# %% [markdown]
# # Token vs. Sentence Embeddings

# %% [markdown]
# Notebook from DeepLearning.AI platform, Course: **Embedding Models: from Architecture to Implementation**
# Created by Vectara
#
# Link to original course, video and notebook: [Token vs. Sentence Embeddings](https://learn.deeplearning.ai/courses/embedding-models-from-architecture-to-implementation/lesson/goj74/token-vs.-sentence-embedding)

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install -U torch
# !pip install -U pandas
# !pip install scipy
# !pip install -U transformers
# !pip install -U datasets
# !pip install -U sentence-transformers
# Out:
# Requirement already satisfied: torch in c:\users\lenak\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: filelock in c:\users\lenak\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\lenak\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in c:\users\lenak\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\lenak\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\lenak\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\lenak\anaconda3\lib\site-packages (from torch) (75.8.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\lenak\anaconda3\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenak\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenak\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: pandas in c:\users\lenak\anaconda3\lib\site-packages (2.2.2)
# Collecting pandas
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\lenak\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenak\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenak\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenak\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenak\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# Successfully installed pandas-2.2.3
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\lenak\anaconda3\Lib\site-packages\~andas'.
#   You can safely remove it manually.
# Requirement already satisfied: scipy in c:\users\lenak\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\lenak\anaconda3\lib\site-packages (from scipy) (1.26.4)
# Requirement already satisfied: transformers in c:\users\lenak\anaconda3\lib\site-packages (4.49.0)
# Requirement already satisfied: filelock in c:\users\lenak\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in c:\users\lenak\anaconda3\lib\site-packages (from transformers) (0.29.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenak\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenak\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenak\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenak\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\lenak\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\lenak\anaconda3\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\lenak\anaconda3\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lenak\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenak\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenak\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\lenak\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenak\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenak\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenak\anaconda3\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenak\anaconda3\lib\site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: datasets in c:\users\lenak\anaconda3\lib\site-packages (3.3.2)
# Collecting datasets
#   Downloading datasets-3.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in c:\users\lenak\anaconda3\lib\site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.24.0 in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (0.29.2)
# Requirement already satisfied: packaging in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenak\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lenak\anaconda3\lib\site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lenak\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenak\anaconda3\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenak\anaconda3\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenak\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\lenak\anaconda3\lib\site-packages (from aiohttp->datasets) (1.11.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenak\anaconda3\lib\site-packages (from huggingface-hub>=0.24.0->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenak\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenak\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenak\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenak\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: colorama in c:\users\lenak\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenak\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenak\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenak\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenak\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.4.1-py3-none-any.whl (487 kB)
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.3.2
#     Uninstalling datasets-3.3.2:
#       Successfully uninstalled datasets-3.3.2
# Successfully installed datasets-3.4.1
# Requirement already satisfied: sentence-transformers in c:\users\lenak\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\lenak\anaconda3\lib\site-packages (from sentence-transformers) (4.49.0)
# Requirement already satisfied: tqdm in c:\users\lenak\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\lenak\anaconda3\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\lenak\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\lenak\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\lenak\anaconda3\lib\site-packages (from sentence-transformers) (0.29.2)
# Requirement already satisfied: Pillow in c:\users\lenak\anaconda3\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in c:\users\lenak\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenak\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\lenak\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenak\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\lenak\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenak\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.11.0)
# Requirement already satisfied: networkx in c:\users\lenak\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\lenak\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\lenak\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.8.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\lenak\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenak\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\lenak\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenak\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenak\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\lenak\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\lenak\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenak\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenak\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenak\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenak\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenak\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenak\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenak\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)

# %%
import torch
import numpy as np
import seaborn as sns
import pandas as pd
import scipy

from transformers import BertModel, BertTokenizer
from datasets import load_dataset

# %% [markdown]
# ## Setup

# %%
model_name = "bert-base-uncased"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

def get_sentence_embedding(sentence):
    encoded_input = tokenizer(sentence, padding=True, truncation=True, return_tensors='pt')
    attention_mask = encoded_input['attention_mask']   # to indicate which tokens are valid and which are padding
    
    # Get the model output (without the specific classification head)
    with torch.no_grad():
        output = model(**encoded_input)

    token_embeddings = output.last_hidden_state
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()

    # mean pooling operation, considering the BERT input_mask and padding
    sentence_embedding = torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    
    return sentence_embedding.flatten().tolist()
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
def cosine_similarity_matrix(features):
    norms = np.linalg.norm(features, axis=1, keepdims=True)
    normalized_features = features / norms
    similarity_matrix = np.inner(normalized_features, normalized_features)
    rounded_similarity_matrix = np.round(similarity_matrix, 4)
    return rounded_similarity_matrix

# %%
# Helper function to plot similarity matrix
def plot_similarity(labels, features, rotation):
    sim = cosine_similarity_matrix(features)
    sns.set_theme(font_scale=1.2)
    g = sns.heatmap(sim, xticklabels=labels, yticklabels=labels, vmin=0, vmax=1, cmap="YlOrRd")
    g.set_xticklabels(labels, rotation=rotation)
    g.set_title("Semantic Textual Similarity")
    return g

# %% [markdown]
# ## Token Embeddings

# %%
messages = [
    # Smartphones
    "I like my phone",
    "My phone is not good.",
    "Your cellphone looks great.",

    # Weather
    "Will it snow tomorrow?",
    "Recently a lot of hurricanes have hit the US",
    "Global warming is real",

    # Food and health
    "An apple a day, keeps the doctors away",
    "Eating strawberries is healthy",
    "Is paleo better than keto?",

    # Asking about age
    "How old are you?",
    "what is your age?",
]

# %%
embeddings = []
for t in messages:
    emb = get_sentence_embedding(t)
    embeddings.append(emb)

plot_similarity(messages, embeddings, 90)
# Out:
# <Axes: title={'center': 'Semantic Textual Similarity'}>

# %%
sts_dataset = load_dataset("mteb/stsbenchmark-sts")
sts = pd.DataFrame({'sent1': sts_dataset['test']['sentence1'], 
                    'sent2': sts_dataset['test']['sentence2'],
                    'score': [x/5 for x in sts_dataset['test']['score']]})
sts.head(10)
# Out:
# README.md:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# train.jsonl.gz:   0%|          | 0.00/278k [00:00<?, ?B/s]
# validation.jsonl.gz:   0%|          | 0.00/86.4k [00:00<?, ?B/s]
# test.jsonl.gz:   0%|          | 0.00/63.2k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/5749 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1500 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1379 [00:00<?, ? examples/s]
#                                            sent1  \
# 0                    A girl is styling her hair.
# 1       A group of men play soccer on the beach.
# 2  One woman is measuring another woman's ankle.
# 3                A man is cutting up a cucumber.
# 4                       A man is playing a harp.
# 5                     A woman is cutting onions.
# 6           A man is riding an electric bicycle.
# 7                    A man is playing the drums.
# 8                       A man is playing guitar.
# 9                     A man is playing a guitar.
#
#                                               sent2   score
# 0                      A girl is brushing her hair.  0.5000
# 1  A group of boys are playing soccer on the beach.  0.7200
# 2           A woman measures another woman's ankle.  1.0000
# 3                      A man is slicing a cucumber.  0.8400
# 4                      A man is playing a keyboard.  0.3000
# 5                          A woman is cutting tofu.  0.3600
# 6                        A man is riding a bicycle.  0.7000
# 7                      A man is playing the guitar.  0.4400
# 8                     A lady is playing the guitar.  0.4400
# 9                       A man is playing a trumpet.  0.3428

# %% [markdown]
# <b>About the scores</b>: These scores are based on human evaluations and in the range 0 to 5 (see https://aclanthology.org/S17-2001.pdf table 1 for how they work). For example "A woman is cutting onions" vs "A woman is cutting tofu" can be considered by a human as in between 2-3 or so. The goal of STS is more to show another example where instead of just our intuition there is some kind of human labeled dataset, albeit it's not exactly a similarity in the sense of cosine but according to the rules of table 1 in the paper above.

# %%
def sim_two_sentences(s1, s2):
    emb1 = get_sentence_embedding(s1)
    emb2 = get_sentence_embedding(s2)
    sim = cosine_similarity_matrix(np.vstack([emb1, emb2]))
    return sim[0,1]

n_examples = 50

sts = sts.head(n_examples)
sts['avg_bert_score'] = np.vectorize(sim_two_sentences) \
                                    (sts['sent1'], sts['sent2'])

# %%
sts.head(10)
# Out:
#                                            sent1  \
# 0                    A girl is styling her hair.
# 1       A group of men play soccer on the beach.
# 2  One woman is measuring another woman's ankle.
# 3                A man is cutting up a cucumber.
# 4                       A man is playing a harp.
# 5                     A woman is cutting onions.
# 6           A man is riding an electric bicycle.
# 7                    A man is playing the drums.
# 8                       A man is playing guitar.
# 9                     A man is playing a guitar.
#
#                                               sent2   score  avg_bert_score
# 0                      A girl is brushing her hair.  0.5000          0.9767
# 1  A group of boys are playing soccer on the beach.  0.7200          0.9615
# 2           A woman measures another woman's ankle.  1.0000          0.9191
# 3                      A man is slicing a cucumber.  0.8400          0.9763
# 4                      A man is playing a keyboard.  0.3000          0.9472
# 5                          A woman is cutting tofu.  0.3600          0.8787
# 6                        A man is riding a bicycle.  0.7000          0.9793
# 7                      A man is playing the guitar.  0.4400          0.9730
# 8                     A lady is playing the guitar.  0.4400          0.9519
# 9                       A man is playing a trumpet.  0.3428          0.9588

# %%
pc = scipy.stats.pearsonr(sts['score'], sts['avg_bert_score'])
print(f'Pearson correlation coefficient = {pc[0]}\np-value = {pc[1]}')
# Out:
# Pearson correlation coefficient = 0.32100172202695454
# p-value = 0.02303013509739929

# %% [markdown]
# ## A better approach: SBERT and Dual Encoders

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
embeddings = []
for t in messages:
    emb = list(model.encode(t))
    embeddings.append(emb)

plot_similarity(messages, embeddings, 90)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# <Axes: title={'center': 'Semantic Textual Similarity'}>

# %%
def sim_two_sentences(s1, s2):
    emb1 = list(model.encode(s1))
    emb2 = list(model.encode(s2))
    sim = cosine_similarity_matrix(np.vstack([emb1, emb2]))
    return sim[0,1]

sts['mini_LM_score'] = np.vectorize(sim_two_sentences)(sts['sent1'], sts['sent2'])
sts.head(10)
# Out:
#                                            sent1  \
# 0                    A girl is styling her hair.
# 1       A group of men play soccer on the beach.
# 2  One woman is measuring another woman's ankle.
# 3                A man is cutting up a cucumber.
# 4                       A man is playing a harp.
# 5                     A woman is cutting onions.
# 6           A man is riding an electric bicycle.
# 7                    A man is playing the drums.
# 8                       A man is playing guitar.
# 9                     A man is playing a guitar.
#
#                                               sent2   score  avg_bert_score  \
# 0                      A girl is brushing her hair.  0.5000          0.9767
# 1  A group of boys are playing soccer on the beach.  0.7200          0.9615
# 2           A woman measures another woman's ankle.  1.0000          0.9191
# 3                      A man is slicing a cucumber.  0.8400          0.9763
# 4                      A man is playing a keyboard.  0.3000          0.9472
# 5                          A woman is cutting tofu.  0.3600          0.8787
# 6                        A man is riding a bicycle.  0.7000          0.9793
# 7                      A man is playing the guitar.  0.4400          0.9730
# 8                     A lady is playing the guitar.  0.4400          0.9519
# 9                       A man is playing a trumpet.  0.3428          0.9588
#
#    mini_LM_score
# 0         0.8052
# 1         0.7886
# 2         0.9465
# 3         0.8820
# 4         0.3556
# 5         0.5017
# 6         0.8074
# 7         0.4757
# 8         0.6182
# 9         0.5096

# %%
pc = scipy.stats.pearsonr(sts['score'], sts['mini_LM_score'])
print(f'Pearson correlation coefficient = {pc[0]}\np-value = {pc[1]}')
# Out:
# Pearson correlation coefficient = 0.9303740673726042
# p-value = 1.4823857251916192e-22
